# %%
number = int(input("enter number: "))
if(number > 0):
    print("possitive number")
elif(number < 0):
    print("negative number")


else:
    print("zero")
# Out:
# enter number:  0
# zero

# %%
num = int(input("enter number: "))
if(num % 2 == 0):
    print("even number")

else:
    print("odd")
# Out:
# enter number:  2
# even number

# %%
marks = int(input("enter your marks: "))
if(marks >= 90):
    print("grade A")
elif(marks >= 75):
    print("grade B")
elif(marks >= 60):
    print("grade C")
elif(marks >= 40):
    print("grade D")

else:
    print("fail")
# Out:
# enter your marks:  87
# grade B

# %%
year = int(input("enter year: "))
if(year % 400 == 0):
    print("leap year")
elif(year % 100 == 0):
    print("not leap")
elif(year % 4 == 0):
    print("leap year")

else:
    print("not leap")
# Out:
# enter year:  2023
# not leap

# %%
num1 = float(input("enter first number: "))
operator = input("enter operator (+,-,*,/): ")
num2 = float(input("enter second number: "))

if operator == "+":
    print("result=", num1 + num2)
elif operator == "-":
    print("result=", num1 - num2)
elif operator == "*":
    print("result=", mum1 * num2)
elif operator == "/":
    if num2!= 0:
        print("result=", num1 / num2)
    else:
        print("cannot divide by zero")

else:
    print("invali")
# Out:
# enter first number:  45
# enter operator (+,-,*,/):  +
# enter second number:  45
# result= 90.0

# %%
age = int(input("enter your age: "))         

if(age >= 18):
    print("you can vote")
else:
    print(" you cannot vote")
# Out:
# enter your age:  15
#  you cannot vote

# %%
num = int(input("enter your number: "))

if(num > 0):
    print("possitive number")
elif(num < 0):
    print("negative number")

else:
    print("zero")
# Out:
# enter your number:  -1
# negative number

# %%
num = int(input("enter your number: "))
if(num % 2 == 0):
          print("even number")
else:
   print("odd")
# Out:
# enter your number:  12
# even number

# %%
marks = int(input("enter your marks: "))

if(marks >= 40 ):
    print("pass")

else:
    print("fail")
# Out:
# enter your marks:  50
# pass

# %%
temperature = int(input("enter temperature: "))

if(temperature >= 30):
    print("hot day")
elif(temperature < 30):
    print("normal day")
# Out:
# enter temperature:  20
# normal day

# %%
a = int(input("enter your number: "))
b = int(input("enter your number: "))

if(a >= b):
    print("a is largest")

elif(a < b):
    print("b is largest")
# Out:
# enter your number:  15
# enter your number:  20
# b is largest

# %%
x = int(input("enter number: "))

if(x % 5 == 0):
    print("divisible number 5")

else:
    print("not divisible number")
# Out:
# enter number:  5
# divisible number 5

# %%
marks = int(input("enter your marks: "))
if(marks >= 90):
    print("excellent")

else:
    print("keep practicing")
# Out:
# enter your marks:  95
# excellent

# %%
num = int(input("enter number: "))

if(num > 0):
    print("not zero")

elif(num < 0):
    print("zero")
# Out:
# enter number:  1
# not zero

# %%
age = int(input("enter your age: "))
if(age >= 13):
    print("adult")
else:
    print("child")
# Out:
# enter your age:  10
# child

# %%
price = int(input("enter price: "))
if(price > 1000):
    print("discount available")
else:
    print("no discount")
# Out:
# enter price:  500
# no discount

# %%
number = int(input("enter number: "))
if(number >=1 and number <= 10):
    print("valid number")

else:
    print("invalid number")
# Out:
# enter number:  12
# invalid number

# %%
units = int(input("enter your electricity units: "))
if units <= 100:
    bill = 0
elif units <= 200:
    bill = (units - 100) * 5
else:
    bill = (100*5) + (units - 200) * 10
print("Total Bill = Rs", bill)
# Out:
# enter your electricity units:  150
# Total Bill = Rs 250

# %%
marks = int(input("enter your marks: "))

if(marks >= 90):
    print("grade A")
elif(marks > 80 and marks <= 90):
    print("grade B")
elif(marks >= 60 and marks <= 80):
    print("grade C")

else:
    print("grade D")
# Out:
# enter your marks:  95
# grade A

# %%
age1 = int(input("enter age of person 1: "))
age2 =  int(input("enter age of person 2: "))
age3 = int(input("enter age of person 3: "))
age4 = int(input("enter age of person 4: "))

if(age1 <= age2 and age1 <= age3 and age1 <= age4):
    print("youngest age is:", age1)
elif(age2 <= age1 and age2 <= age3 and age2 <= age4):
    print("youngest agge is:",age2)
elif(age3 <= age1 and age3 <= age2 and age3 <= age4):
    print("youngest age is:", age3)
else:
    ("youngest age is:", age4)
# Out:
# enter age of person 1:  12
# enter age of person 2:  18
# enter age of person 3:  20
# enter age of person 4:  22
# youngest age is: 12

# %%
salary = float(input("enter your salary: "))
years = int(input("enter years of service: "))

if(years > 10):
    bonus = salary * 10 / 100
elif(years >= 6 and years <= 10):
    bonus = salary * 8 / 100

else:
    bonus = salary * 5 / 100

    print("Bonus Amount =", bonus)
# Out:
# enter your salary:  25000
# enter years of service:  5
# Bonus Amount = 1250.0

# %%
num1 = int(input("enter your number: "))
num2 = int(input("enter your number: "))
num3 = int(input("enter your number: "))

if(num1 > num2 and num1 > num3) or (num1 > num3 and num1 < num2):
    second_largestb = num1
elif(num2 > num1 and num2 < num3) or (num2 > num3 and num2 < num1):
    second_largest = num2
else:
    second_largest = num3

    print("second largest number is:", second_largest)
# Out:
# enter your number:  10
# enter your number:  20
# enter your number:  15
# second largest number is: 15

# %%
price = int(input("enter price: "))
if(price > 10000):
    Discount = 20
elif(price > 7000 and price <= 10000):
    Discount = 15
elif(price <= 7000):
    Discount = 10 

print(f"discount = {Discount}%")
# Out:
# enter price:  11000
# discount = 20%

# %%
english_marks = int(input("enter your english marks: "))
math_marks = int(input("enter your math marks: "))
science_marks = int(input("enter your science marks: "))
social_studies_marks = int(input("enter your social_studies marks: "))

if(english_marks >= 80 and math_marks >= 80 and science_marks >= 80):
    print("stream allotted: stream science")
elif(english_marks >= 80 and math_marks > 50 and science_marks > 50):
    print("stream allotted: stream commerce ")
elif(english_marks >= 80 and social_studies_marks >= 80):
    print(" stream allotted: humanities")

else:
    print("no stream based on these criteria.")
# Out:
# enter your english marks:  85
# enter your math marks:  45
# enter your science marks:  40
# enter your social_studies marks:  90
#  stream allotted: humanities

# %%
number = int(input("enter number: "))

if(number % 5 == 0):
    print("Hello")

else:
    print("Bye")
# Out:
# enter number:  22
# Bye

# %%
number = int(input("enter number: "))
last_digit = number % 10

if(last_digit % 3 == 0):
    print(" divisible number")

else:
    print("not divisible")
# Out:
# enter number:  25
# not divisible

# %%
number = int(input("enter number: "))

if(number >= 100 and number <= 999):
    print("Three digit number")
else:
    print("Not three digit number")
# Out:
# enter number:  850
# Three digit number

# %%
units = int(input("enter electricity units: "))

if(units <= 100):
    bill = units * 5
elif(units <= 200):
    bill = units * 7
else:
    bill = units * 10

    print("total Bill =", bill)
# Out:
# enter electricity units:  250
# total Bill = 2500

# %%
month = int(input("enter month mumber(1-12): "))


if(month == 1):
    print("january")
elif(month == 2):
    print("february")
elif(month == 3):
    print("march")
elif(month == 4):
    print("april")
elif(month == 5):
    print("may")
elif(month == 6):
    print("june")
elif(month == 7):
    print("july")
elif(month == 8):
    print("august")
elif(month == 9):
    print("setember")
elif(month == 10):
    print("octuber")
elif(month == 11):
    print("november")
elif(month == 12):
    print("december")

else:
    print("invalid number")
# Out:
# enter month mumber(1-12):  11
# november

# %%
income = float(input("enter your income: "))

if(income <= 250000):
    tax = 0
elif(income <= 500000):
    tax = income * 5
elif(income <= 1000000):
    tax = income * 20
else:
    tax = income * 30

print("Tax Amount=",tax)
# Out:
# enter your income:  500000
# Tax Amount= 2500000.0

# %%
year = int(input("enter year"))

if(year % 400 == 0):
    print("leap year")
elif(year % 100 == 0):
    print("not leap")
elif(year % 4 == 0):
    print("leap year")

else:
    print("not leap")
# Out:
# enter year 2024
# leap year
