# %%
def vote_or_not(age):                                       #Q no1: write a program that asks the user to enter age. if the
    """This function check person can vote or not"""         #  age is 18 or above. print "you can vote" otherwise print"you cannot vote.
    if age > 18:
        return "you can vote"

    else:
        return "you can not vote"

# %%
user_age= int(input("enter your age:"))
print(vote_or_not(user_age))
# Out:
# enter your age: 40
# you can vote

# %%
def num_checker(number):           # Q no2: write a program that asks the user to enter a number. check whether the number
    if number > 0:                  #      is positive or negative.
        return "positive number"
    else:
        return "negative number"

# %%
num = int(input("enter number:"))
print(num_checker(num))
# Out:
# enter number: -4
# negative number

# %%
def even_or_cheker(num):             #  Q no3: write a program that asks the user to enter a number
    if num %2 == 0:                    #        check whether the number is even or odd.
        return "even number"
    else:
        return "odd number"

# %%
number = int(input("enter number:"))
print(even_or_cheker(number))
# Out:
# enter number: 4
# even number

# %%
def marks_cheker(marks):               # Q no4: write a program that asks the user to enter marks if marks are 40
    if marks >= 40:                      #       or above, print "pass" otherwise, print "fail".
        return "pass"
    else:
        return "fail"

# %%
num = int(input("enter your marks:"))
print(marks_cheker(num))
# Out:
# enter your marks: 45
# pass

# %%
password = "python123"                     # Q no5: write a program that asks the user to enter a password. if the password
                                             #       is "python123" print "login successful" otherwise, print "wrong password"

# %%
def password_login(password):
    if password == password:
        return "login successful"
    else:
        return "wrong password"

# %%
print(password_login("python123"))
# Out:
# login successful

# %%
def weather_cheker(temperature):           #    Q no6: write a program that asks the user to enter the temperature.
    if temperature > 30                        #       if the temperature is greater than 30.print"hot day" otherwise, print "normal"
        return "it is a hot day"
    else:
        return "normal day"

# %%
temp = int(input("enter temperature:"))
print(weather_cheker(temp))
# Out:
# enter temperature: 35
# it is a hot day

# %%
def num_checker(num1,num2):                  #  Q no7: write a program that asks the user to enter two numbers. 
    if num1 > num2:                             #      print which number is greater.
        return "num1 is greater"
    else:
        return "num2 isgreater"

# %%
num_checker(12,23)
# Out:
# 'num2 isgreater'

# %%
def diviser(num):                       #  Q no8: write a program that asks the user to ente a number.
    if num %5 == 0:                        #     check whether the number is divisible 5 or not.
        return "divide by 5"
    else:
        return "not divide by 5"

# %%
num = int(input("enter number:"))
print(diviser(num))
# Out:
# enter number: 10
# divide by 5

# %%
user_name = "admin"              # Q no9: write a program that asks the user to enter their username.if the 
                                      #   username is "admin". print "welcome admin" otherwise, print "welcome user".

# %%
def user_name_checker(username):
    if username == user_name:
        return "welcome admin"
    else:
        return "welcome user"

# %%
print(user_name_checker("asif"))
print(user_name_checker("admin"))
# Out:
# welcome user
# welcome admin

# %%
def score_check(score):                   #  Q no10: write a program that asks the user to enter their exam score.
    if score >= 90:                            #  if the score is 90 or above. print "excellent" otherwise, print "keep practicing"
        return "excellent"
    else:
        return "keep practicing"

# %%
scores = int(input("enter score:"))
print(score_check(scores))
# Out:
# enter score: 95
# excellent

# %%
def num_zero_or_not(number1):            #Q no11: write a program that asks te user to enter a number check
    if number1 == 0:                              #    whether the number is zero or not zero.
        return "zero"
    else:
        return " not zero"

# %%
num1 = int(input("enter number:"))       
print(num_zero_or_not(num1))
# Out:
# enter number: 2
#  not zero

# %%
def age_cheker(age):                      # Q no12: write a program that asks the user to enter their age.
    if age < 13:                      #  if age is less than 13. print "child" otherwise, print "teenager or adukt".
        return "child"
    elif age < 20:
        return "teenager"
    else:
        return "adult"

# %%
age = int(input("enter age:"))
print(age_cheker(age))
# Out:
# enter age: 13
# teenager

# %%
def cha_chaker(charater):               #   Q no13: write a program that asks the user to enter a character
    if charater == "a":                                # check whether the character is 'a' or not.
       return True
    else:
        return False

# %%
char =input("enter character:")
print(cha_chaker(char))
# Out:
# enter character: a
# True

# %%
# Q no14: write program that asks the user to enter the price of an 
# if the price is greater than 1000 print "discount available" otherwise "no discound"

# %%
def dis_chacker(price):
    if price > 1000:
        return "discount available"
    else:
        return "no discount"

# %%
price = int(input("enter price:"))
print(dis_chacker(price))
# Out:
# enter price: 1100
# discount available

# %%
# Q no15: write a program that asks the user to enter a number. if the number is
# between 1 and 10. print "valid number" otherwise. "invalid number".

# %%
def validity(number):
    if 1 <= number <= 10:
        return "valid number"
    else:
        return "invalid number"

# %%
num = int(input("enter number:"))
print(validity(num))
# Out:
# enter number: 11
# invalid number
