# %%
# escape characters
# types of characters

# \n
# \b
# \t
# \r
# \'
# \"
# \\

# %%
print("hello \n world")
# Out:
# hello
#  world

# %%
print("python\b\b\bclass")
# Out:
# pytclass

# %%
print("hello\tworld")
# Out:
# hello	world

# %%
print('it\'s python class')
# Out:
# it's python class

# %%
print("its raining in \"noida\" ")
# Out:
# its raining in "noida"

# %%
# python ray string

# my_path1 = "C:\\Users\\Affan\\Documents\\python notebook.txt"
# my_path2 = "C:/Users/Affan/Documents/python notebook.txt"
my_path  = r"C:\Users\Affan\Documents\python notebook.txt"
with open(my_path2)  as file:

     content = file.read()

     print(content)
# Out:
# i am learnig python

# %%
             # input

name = input("Enter your name:")
age = input("Enter your age:")
city = input("Enter your city:")

print(f"hi  {name} how can i help you? your age is {age} your city is {city}")
# Out:
# Enter your name: asif
# Enter your age: 20
# Enter your city: delhi
# hi  asif how can i help you? your age is 20 your city is delhi

# %%
marks = int(input("Enter your marks:"))
print(marks)
print(type(marks))
# Out:
# Enter your marks: 50
# 50
# <class 'int'>

# %%
name = input("Enter your name:")
age = input("Enter your age:")
city = input("Enter your city:")

print(f"hi  {name.capitalize()} how can i help you? your age is {age} your city is {city.capitalize()}")
# Out:
# Enter your name: asif
# Enter your age: 20
# Enter your city: delhi
# hi  Asif how can i help you? your age is 20 your city is Delhi
